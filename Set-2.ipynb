# %% [markdown]
# # Problem-set-2

# %% [markdown]
# 1.WAP to add two numbers.

# %%
def sum_func(a,b):
    print(a+b)

# %%
# EXAMPLE

sum_func(9,10)

# %% [markdown]
# 2.WAP to find reminder when a number os divided by 7.

# %%
def rem_7(a):
    return a%7

# %%
# EXAMPLE

rem_7(9)

# %% [markdown]
# 3. Check the type of variable assigned using input() function

# %%
def typ(a):
    print(type(a))

# %%
#EXAMPLE

typ(9)
# Out:
# <class 'int'>

# %% [markdown]
# 4.Use comparison opt to find out wether a given variable "a" is greater tn "b" or not.

# %%
def grt(a,b):
    if a>b:
        return True
    else:
        return False

# %%
#EXAMPLE

grt(9,10)

# %% [markdown]
# 5.WAP to find average of two number entered by user.

# %%
def avg(a,b):
    return (a+b)/2

# %%
#EXAMPLE

avg(10,11)
# Out:
# 10.5

# %% [markdown]
# 6.WAP to calulate square of a number entered by the user.

# %%
def squ(a):
    return a**2

# %%
#EXAMPLE

squ(100)
