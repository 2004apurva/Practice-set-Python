# %% [markdown]
# # Problem-Set-4

# %% [markdown]
# 1.WAP a program to store seven fruits in a list entered by the user.

# %%
def name(*args):
    list=[]
    for i in range(len(args)):
        
        return list

# %%
lists=["apple","mango","orange","Grapes","banana"]

# %%
lists
# Out:
# ['apple', 'mango', 'orange', 'Grapes', 'banana']

# %% [markdown]
# 2.WAP a program to accept marks of 6 student and display them in a shorted manner.

# %%
list=[1,2,99,7,5,6]
list.sort()

# %%
list
# Out:
# [1, 2, 5, 6, 7, 99]

# %% [markdown]
# 3.Check that a tuple cannot be changed in python.

# %%
tuples=(1,2,3,4,5,6)

# %%
tuples.append(9) #Tuples cannot be changed because they are immutable

# %% [markdown]
# 4.WAP to sum a list with 4 numbers.

# %%
list=[1,2,3,4]
sum=0
for i in list:
    sum+=i
print(sum)
# Out:
# 10

# %% [markdown]
# 5.WAP to count the number of zeros in the tuple.

# %%
a=(7,0,8,0,0,9)
zero=0

for i in a:
    if i==0:
        zero+=1
print(zero)
# Out:
# 3
