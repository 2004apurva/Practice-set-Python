# %% [markdown]
# # Problem-Set-6

# %% [markdown]
# 1.WAP to find greatest of four number entered by th user.

# %%
def num(a,b,c,d):
    if a>b and a>c and a>d:
        print( a ," is greatest number")

    elif b>c and b>a and b>d:
        print( b ," is greates number")

    elif c>a and c>b and c>d:
        print( c, " is greatest number")

    elif d>a and d>c and d>b:
        print( d ," is greatest number")

# %%
num(1,2,3,4)
# Out:
# 4  is greatest number

# %% [markdown]
# 2.WAP to find out whether a student is pass or fail,if it requries total 40% and at lest 33% in rach subject and take marks as an input from the user.

# %%
a=int(input("Enter Maths marks"))
b=int(input("Enter English marks"))

total_passing_marks=(40/(a+b))*100

first_subject=(33/a)*100

second_subject=(33/b)*100

if total_passing_marks>40:
    if first_subject>33 and second_subject>33:
        print("Student is pass")

# %% [markdown]
# 3.Detecting spam message from message.

# %%
#defining funtion to take message
def message_to_user(message):

#list that contain smap message
    spam_list=["Make money","byu now"]
    for i in spam_list:

        if i in message:
            print("Spam message")

# %%
message_to_user("Make money")
# Out:
# Spam message

# %% [markdown]
# 4.WAP to find wether a given username contain less than 10 char or not.

# %%
def user_name(name):
    if len(name)>10:
        print("username is greater than 10 char")
    
    else:
        print("username is perfect")

# %%
user_name("Apurva_")
# Out:
# username is perfect

# %% [markdown]
# 5.WAP which finds out whether a given name is presented in a list or not.

# %%
list=["Apurva","Sachin","Harsh","Vivek","Kunal"]

def given_name(name):
    if name in list:
        print("Name is present")
    else:
        print("NAme not present")

# %%
given_name("Sachin")
# Out:
# Name is present

# %% [markdown]
# 6.WAP to calcu the gread of a student from passing scheme.

# %%
def student_marks(marks):
    if 90<marks<100:
        print("EX")
    elif 80<marks<89:
        print("A")
    elif 70<marks<79:
        print("B")
    elif 60<marks<69:
        print("C")
    elif 50<marks<59:
        print("D")
    elif marks<50:
        print("F")

# %%
student_marks(56)
# Out:
# D

# %% [markdown]
# 7.WAP to find out whether a given post is taliking about "Harry" ot not.

# %%
def talking_record(taliking):
    
    if "harry" in taliking:
        print("Present")

# %%
talking_record("harry")
# Out:
# Present
