# %% [markdown]
# # Problem-set-1

# %% [markdown]
# 1.Write a prigram to print Twinkle Twinkle Little Star Poem in Python

# %%
print("Twinkle Twinkle Little Star")

# %% [markdown]
# 2.write a program to the context of directory using
